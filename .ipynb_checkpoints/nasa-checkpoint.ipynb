# %%
import pandas as pd
import numpy as np
import os
import geopandas
import matplotlib.pyplot as plt
import descartes
from shapely.geometry import Point, Polygon
# %matplotlib inline

# %%
df = pd.read_csv('MODIS_C6_South_Asia_7d.csv')
df
# Out:
#       latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       27.260     92.144       313.9   1.0    1.0  2020-01-11       430
# 1       26.544     94.701       301.6   1.1    1.0  2020-01-11       430
# 2       26.605     93.104       306.1   1.0    1.0  2020-01-11       430
# 3       25.216     94.512       301.4   1.1    1.0  2020-01-11       435
# 4       23.779     86.399       311.4   1.8    1.3  2020-01-11       435
# ...        ...        ...         ...   ...    ...         ...       ...
# 2891    32.939     71.787       302.0   2.4    1.5  2020-01-18       750
# 2892    32.894     71.660       310.3   2.5    1.5  2020-01-18       750
# 2893    33.660     73.035       303.6   1.9    1.4  2020-01-18       750
# 2894    33.664     73.029       304.3   1.9    1.4  2020-01-18       750
# 2895    38.425     77.348       305.9   1.0    1.0  2020-01-18       755
#
#      satellite  confidence version  bright_t31   frp daynight
# 0            T          74  6.0NRT       283.8  16.1        D
# 1            T          48  6.0NRT       289.0   6.0        D
# 2            T           0  6.0NRT       295.7   5.7        D
# 3            T          47  6.0NRT       289.2   5.9        D
# 4            T          69  6.0NRT       295.4  19.2        D
# ...        ...         ...     ...         ...   ...      ...
# 2891         A          50  6.0NRT       287.6  15.0        D
# 2892         A          70  6.0NRT       288.2  32.8        D
# 2893         A          54  6.0NRT       287.1  13.7        D
# 2894         A          58  6.0NRT       287.1  15.5        D
# 2895         A          47  6.0NRT       276.6   9.4        D
#
# [2896 rows x 13 columns]

# %%
df1 = pd.read_csv('VNP14IMGTDL_NRT_South_Asia_7d.csv')
df1.shape
# Out:
# (19010, 13)

# %% [markdown]
# 29"30'N to 32"32'N latitude and 73"55'E to 76"50'E longitude.

# %%
df1 = df1.loc[(df1['latitude']>8) & (df1['latitude']<14) & (df1['longitude']>76) & (df1['longitude']<81)]

# %%
29.5 to 32.533   
73.916 to 76.8333

# %%
32 + 32/60
# Out:
# 32.53333333333333

# %%
73 + 55/60
# Out:
# 73.91666666666667

# %%
76 + 50/60
# Out:
# 76.83333333333333

# %%
gdf = geopandas.GeoDataFrame(df1, geometry=geopandas.points_from_xy(df1.longitude, df1.latitude))

# %%
gdf.head()
# Out:
#       latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 1159  30.61898   76.11717       326.4  0.44   0.62  2020-01-11       706
# 1288  30.30879   75.90305       332.0  0.52   0.67  2020-01-11       848
# 4049  31.11794   76.08872       329.9  0.56   0.52  2020-01-12       830
# 7795  32.13127   74.17829       298.1  0.44   0.38  2020-01-13      2036
# 7798  30.88275   75.99367       295.6  0.39   0.36  2020-01-13      2036
#
#      satellite confidence version  bright_ti5  frp daynight  \
# 1159         N    nominal  1.0NRT       287.5  1.9        D
# 1288         N    nominal  1.0NRT       283.2  4.0        D
# 4049         N    nominal  1.0NRT       270.7  4.5        D
# 7795         N    nominal  1.0NRT       278.5  0.4        N
# 7798         N    nominal  1.0NRT       279.8  0.3        N
#
#                        geometry
# 1159  POINT (76.11717 30.61898)
# 1288  POINT (75.90305 30.30879)
# 4049  POINT (76.08872 31.11794)
# 7795  POINT (74.17829 32.13127)
# 7798  POINT (75.99367 30.88275)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world[world.continent == 'India'].plot(
    color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()
# Out:
# /home/naveenggmu/.local/lib/python3.7/site-packages/geopandas/plotting.py:510: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %%
geopandas.datasets.available
# Out:
# ['naturalearth_lowres', 'naturalearth_cities', 'nybb']

# %%
print(world.continent)
# Out:
# 0            Oceania
# 1             Africa
# 2             Africa
# 3      North America
# 4      North America
#            ...
# 172           Europe
# 173           Europe
# 174           Europe
# 175    North America
# 176           Africa
# Name: continent, Length: 177, dtype: object

# %%
states = geopandas.read_file('/home/naveenggmu/Downloads/NASA data/Igismap/Indian_States.shp')

# %%
fig,ax = plt.subplots(figsize = (15,15))
states.plot(ax = ax)

# %%
g = [Point(xy) for xy in zip(df1['longitude'], df1['latitude'])]
g
# Out:
# [<shapely.geometry.point.Point at 0x7f30892cab90>,
#  <shapely.geometry.point.Point at 0x7f30892821d0>,
#  <shapely.geometry.point.Point at 0x7f3089282e50>,
#  <shapely.geometry.point.Point at 0x7f3089282390>,
#  <shapely.geometry.point.Point at 0x7f3089282ed0>,
#  <shapely.geometry.point.Point at 0x7f3089282250>,
#  <shapely.geometry.point.Point at 0x7f3089282650>,
#  <shapely.geometry.point.Point at 0x7f3089282110>,
#  <shapely.geometry.point.Point at 0x7f30892829d0>,
#  <shapely.geometry.point.Point at 0x7f3089282a50>,
#  <shapely.geometry.point.Point at 0x7f3089282710>,
#  <shapely.geometry.point.Point at 0x7f3089282b10>,
#  <shapely.geometry.point.Point at 0x7f3089282510>,
#  <shapely.geometry.point.Point at 0x7f3089282810>,
#  <shapely.geometry.point.Point at 0x7f3089282210>,
#  <shapely.geometry.point.Point at 0x7f3089282cd0>,
#  <shapely.geometry.point.Point at 0x7f3089282c90>,
#  <shapely.geometry.point.Point at 0x7f3089282790>,
#  <shapely.geometry.point.Point at 0x7f30881bdfd0>,
#  <shapely.geometry.point.Point at 0x7f30881bd990>,
#  <shapely.geometry.point.Point at 0x7f30881bdad0>,
#  <shapely.geometry.point.Point at 0x7f30881bd410>,
#  <shapely.geometry.point.Point at 0x7f30881bd450>,
#  <shapely.geometry.point.Point at 0x7f30881bdb10>,
#  <shapely.geometry.point.Point at 0x7f3089298cd0>,
#  <shapely.geometry.point.Point at 0x7f30892983d0>,
#  <shapely.geometry.point.Point at 0x7f3089298690>,
#  <shapely.geometry.point.Point at 0x7f3089298e10>,
#  <shapely.geometry.point.Point at 0x7f3089298390>,
#  <shapely.geometry.point.Point at 0x7f3089298c10>,
#  <shapely.geometry.point.Point at 0x7f30892985d0>,
#  <shapely.geometry.point.Point at 0x7f3089298ed0>,
#  <shapely.geometry.point.Point at 0x7f3089298dd0>,
#  <shapely.geometry.point.Point at 0x7f3089298fd0>,
#  <shapely.geometry.point.Point at 0x7f3089298790>,
#  <shapely.geometry.point.Point at 0x7f3089298950>,
#  <shapely.geometry.point.Point at 0x7f3089298490>,
#  <shapely.geometry.point.Point at 0x7f3089298c90>,
#  <shapely.geometry.point.Point at 0x7f3089298890>,
#  <shapely.geometry.point.Point at 0x7f30892982d0>,
#  <shapely.geometry.point.Point at 0x7f3089298710>,
#  <shapely.geometry.point.Point at 0x7f3089298910>,
#  <shapely.geometry.point.Point at 0x7f3089298a90>,
#  <shapely.geometry.point.Point at 0x7f30892980d0>,
#  <shapely.geometry.point.Point at 0x7f3089298ad0>,
#  <shapely.geometry.point.Point at 0x7f30892989d0>,
#  <shapely.geometry.point.Point at 0x7f3089298450>,
#  <shapely.geometry.point.Point at 0x7f30892987d0>,
#  <shapely.geometry.point.Point at 0x7f3089298d90>,
#  <shapely.geometry.point.Point at 0x7f3089298b10>,
#  <shapely.geometry.point.Point at 0x7f3089298050>,
#  <shapely.geometry.point.Point at 0x7f3089298a10>,
#  <shapely.geometry.point.Point at 0x7f3089298090>,
#  <shapely.geometry.point.Point at 0x7f30892986d0>,
#  <shapely.geometry.point.Point at 0x7f3089298d10>,
#  <shapely.geometry.point.Point at 0x7f3089298a50>,
#  <shapely.geometry.point.Point at 0x7f3089298f10>,
#  <shapely.geometry.point.Point at 0x7f3089298d50>,
#  <shapely.geometry.point.Point at 0x7f3089298b90>,
#  <shapely.geometry.point.Point at 0x7f3089298590>,
#  <shapely.geometry.point.Point at 0x7f30892981d0>,
#  <shapely.geometry.point.Point at 0x7f3089298510>,
#  <shapely.geometry.point.Point at 0x7f3089298350>,
#  <shapely.geometry.point.Point at 0x7f3089298750>,
#  <shapely.geometry.point.Point at 0x7f3089298650>,
#  <shapely.geometry.point.Point at 0x7f3089298150>,
#  <shapely.geometry.point.Point at 0x7f3089292810>,
#  <shapely.geometry.point.Point at 0x7f3089292ad0>,
#  <shapely.geometry.point.Point at 0x7f30892926d0>,
#  <shapely.geometry.point.Point at 0x7f3089292ed0>,
#  <shapely.geometry.point.Point at 0x7f30892927d0>,
#  <shapely.geometry.point.Point at 0x7f3089292bd0>,
#  <shapely.geometry.point.Point at 0x7f3089292710>,
#  <shapely.geometry.point.Point at 0x7f3089292110>,
#  <shapely.geometry.point.Point at 0x7f3089292190>,
#  <shapely.geometry.point.Point at 0x7f3089292790>,
#  <shapely.geometry.point.Point at 0x7f3089292d50>,
#  <shapely.geometry.point.Point at 0x7f30892921d0>,
#  <shapely.geometry.point.Point at 0x7f30892928d0>,
#  <shapely.geometry.point.Point at 0x7f3089292b10>,
#  <shapely.geometry.point.Point at 0x7f30892923d0>,
#  <shapely.geometry.point.Point at 0x7f3089292550>,
#  <shapely.geometry.point.Point at 0x7f30892925d0>,
#  <shapely.geometry.point.Point at 0x7f3089292290>,
#  <shapely.geometry.point.Point at 0x7f3089292c10>,
#  <shapely.geometry.point.Point at 0x7f3089292150>,
#  <shapely.geometry.point.Point at 0x7f3089292d10>,
#  <shapely.geometry.point.Point at 0x7f3089292a90>,
#  <shapely.geometry.point.Point at 0x7f3089292090>,
#  <shapely.geometry.point.Point at 0x7f3089292410>,
#  <shapely.geometry.point.Point at 0x7f3089292fd0>,
#  <shapely.geometry.point.Point at 0x7f3089292390>,
#  <shapely.geometry.point.Point at 0x7f3089292f50>,
#  <shapely.geometry.point.Point at 0x7f3089276610>,
#  <shapely.geometry.point.Point at 0x7f3089276250>,
#  <shapely.geometry.point.Point at 0x7f3089276d90>,
#  <shapely.geometry.point.Point at 0x7f3089276a90>,
#  <shapely.geometry.point.Point at 0x7f3089276ad0>,
#  <shapely.geometry.point.Point at 0x7f3089276990>,
#  <shapely.geometry.point.Point at 0x7f30892762d0>,
#  <shapely.geometry.point.Point at 0x7f3089276cd0>,
#  <shapely.geometry.point.Point at 0x7f3089276310>,
#  <shapely.geometry.point.Point at 0x7f3089276ed0>,
#  <shapely.geometry.point.Point at 0x7f30892764d0>,
#  <shapely.geometry.point.Point at 0x7f3089276b10>,
#  <shapely.geometry.point.Point at 0x7f3089276790>,
#  <shapely.geometry.point.Point at 0x7f3089276910>,
#  <shapely.geometry.point.Point at 0x7f3089276150>,
#  <shapely.geometry.point.Point at 0x7f30892760d0>,
#  <shapely.geometry.point.Point at 0x7f3089276b50>,
#  <shapely.geometry.point.Point at 0x7f3088c90690>,
#  <shapely.geometry.point.Point at 0x7f3088c90250>,
#  <shapely.geometry.point.Point at 0x7f3088c90390>,
#  <shapely.geometry.point.Point at 0x7f3088c90510>,
#  <shapely.geometry.point.Point at 0x7f3088c90650>,
#  <shapely.geometry.point.Point at 0x7f3088c90850>,
#  <shapely.geometry.point.Point at 0x7f3088c90210>,
#  <shapely.geometry.point.Point at 0x7f3088c90890>,
#  <shapely.geometry.point.Point at 0x7f3088c90790>,
#  <shapely.geometry.point.Point at 0x7f3088c90710>,
#  <shapely.geometry.point.Point at 0x7f3088c90750>,
#  <shapely.geometry.point.Point at 0x7f3088c90810>,
#  <shapely.geometry.point.Point at 0x7f3088c907d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90090>,
#  <shapely.geometry.point.Point at 0x7f3088c90350>,
#  <shapely.geometry.point.Point at 0x7f3088c90950>,
#  <shapely.geometry.point.Point at 0x7f3088c906d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90190>,
#  <shapely.geometry.point.Point at 0x7f3088c90110>,
#  <shapely.geometry.point.Point at 0x7f3088c900d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90410>,
#  <shapely.geometry.point.Point at 0x7f3088c904d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90290>,
#  <shapely.geometry.point.Point at 0x7f3088c90310>,
#  <shapely.geometry.point.Point at 0x7f3088c901d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90150>,
#  <shapely.geometry.point.Point at 0x7f3088c90590>,
#  <shapely.geometry.point.Point at 0x7f3088c90610>,
#  <shapely.geometry.point.Point at 0x7f3088c905d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90550>,
#  <shapely.geometry.point.Point at 0x7f3088c90450>,
#  <shapely.geometry.point.Point at 0x7f3088c90490>,
#  <shapely.geometry.point.Point at 0x7f3088c902d0>,
#  <shapely.geometry.point.Point at 0x7f3088c903d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90990>,
#  <shapely.geometry.point.Point at 0x7f3088c90050>,
#  <shapely.geometry.point.Point at 0x7f3088c909d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90a50>,
#  <shapely.geometry.point.Point at 0x7f3088c90a10>,
#  <shapely.geometry.point.Point at 0x7f3088c90a90>,
#  <shapely.geometry.point.Point at 0x7f3088c90ad0>,
#  <shapely.geometry.point.Point at 0x7f3088c90b10>,
#  <shapely.geometry.point.Point at 0x7f3088c90b50>,
#  <shapely.geometry.point.Point at 0x7f3088c90b90>,
#  <shapely.geometry.point.Point at 0x7f3088c90bd0>,
#  <shapely.geometry.point.Point at 0x7f3088c90c10>,
#  <shapely.geometry.point.Point at 0x7f3088c90c50>,
#  <shapely.geometry.point.Point at 0x7f3088c90910>,
#  <shapely.geometry.point.Point at 0x7f3088c908d0>,
#  <shapely.geometry.point.Point at 0x7f3088c90d10>,
#  <shapely.geometry.point.Point at 0x7f3088c90c90>,
#  <shapely.geometry.point.Point at 0x7f3088c90d50>,
#  <shapely.geometry.point.Point at 0x7f3088c90dd0>,
#  <shapely.geometry.point.Point at 0x7f3088c90cd0>,
#  <shapely.geometry.point.Point at 0x7f3088c90f90>,
#  <shapely.geometry.point.Point at 0x7f3088c90f50>,
#  <shapely.geometry.point.Point at 0x7f3088c90d90>,
#  <shapely.geometry.point.Point at 0x7f3088c90f10>,
#  <shapely.geometry.point.Point at 0x7f3088c90e50>,
#  <shapely.geometry.point.Point at 0x7f3088c90e10>,
#  <shapely.geometry.point.Point at 0x7f3089280050>,
#  <shapely.geometry.point.Point at 0x7f30892801d0>,
#  <shapely.geometry.point.Point at 0x7f3089280210>,
#  <shapely.geometry.point.Point at 0x7f3089280090>,
#  <shapely.geometry.point.Point at 0x7f3089280350>,
#  <shapely.geometry.point.Point at 0x7f3089280390>,
#  <shapely.geometry.point.Point at 0x7f30892800d0>,
#  <shapely.geometry.point.Point at 0x7f3089280150>,
#  <shapely.geometry.point.Point at 0x7f3089280510>,
#  <shapely.geometry.point.Point at 0x7f30892803d0>,
#  <shapely.geometry.point.Point at 0x7f30892802d0>,
#  <shapely.geometry.point.Point at 0x7f3089280690>,
#  <shapely.geometry.point.Point at 0x7f3089280550>,
#  <shapely.geometry.point.Point at 0x7f3089280450>,
#  <shapely.geometry.point.Point at 0x7f3089280810>,
#  <shapely.geometry.point.Point at 0x7f30892806d0>,
#  <shapely.geometry.point.Point at 0x7f30892805d0>,
#  <shapely.geometry.point.Point at 0x7f3089280990>,
#  <shapely.geometry.point.Point at 0x7f3089280850>,
#  <shapely.geometry.point.Point at 0x7f3089280750>,
#  <shapely.geometry.point.Point at 0x7f3089280b10>,
#  <shapely.geometry.point.Point at 0x7f30892809d0>,
#  <shapely.geometry.point.Point at 0x7f3089280b90>,
#  <shapely.geometry.point.Point at 0x7f3089280bd0>,
#  <shapely.geometry.point.Point at 0x7f3089280b50>,
#  <shapely.geometry.point.Point at 0x7f30892808d0>,
#  <shapely.geometry.point.Point at 0x7f3089280d90>,
#  <shapely.geometry.point.Point at 0x7f3089280c50>,
#  <shapely.geometry.point.Point at 0x7f3089280a50>,
#  <shapely.geometry.point.Point at 0x7f3089280f10>,
#  <shapely.geometry.point.Point at 0x7f3089280dd0>,
#  <shapely.geometry.point.Point at 0x7f3089280cd0>,
#  <shapely.geometry.point.Point at 0x7f3089280f50>,
#  <shapely.geometry.point.Point at 0x7f3089280e90>,
#  <shapely.geometry.point.Point at 0x7f3089280910>,
#  <shapely.geometry.point.Point at 0x7f3089280890>,
#  <shapely.geometry.point.Point at 0x7f3089280e10>,
#  <shapely.geometry.point.Point at 0x7f3089280fd0>,
#  <shapely.geometry.point.Point at 0x7f3089280410>,
#  <shapely.geometry.point.Point at 0x7f3089280790>,
#  <shapely.geometry.point.Point at 0x7f3089280a90>,
#  <shapely.geometry.point.Point at 0x7f3089280310>,
#  <shapely.geometry.point.Point at 0x7f3089280f90>,
#  <shapely.geometry.point.Point at 0x7f3089280290>,
#  <shapely.geometry.point.Point at 0x7f3089280710>,
#  <shapely.geometry.point.Point at 0x7f3089280590>,
#  <shapely.geometry.point.Point at 0x7f3089280110>,
#  <shapely.geometry.point.Point at 0x7f3089280c90>,
#  <shapely.geometry.point.Point at 0x7f3089265090>,
#  <shapely.geometry.point.Point at 0x7f3089265050>,
#  <shapely.geometry.point.Point at 0x7f3089265210>,
#  <shapely.geometry.point.Point at 0x7f3089265250>,
#  <shapely.geometry.point.Point at 0x7f30892650d0>,
#  <shapely.geometry.point.Point at 0x7f3089265390>,
#  <shapely.geometry.point.Point at 0x7f30892653d0>,
#  <shapely.geometry.point.Point at 0x7f3089265110>,
#  <shapely.geometry.point.Point at 0x7f3089265190>,
#  <shapely.geometry.point.Point at 0x7f3089265550>,
#  <shapely.geometry.point.Point at 0x7f3089265410>,
#  <shapely.geometry.point.Point at 0x7f3089265310>,
#  <shapely.geometry.point.Point at 0x7f30892656d0>,
#  <shapely.geometry.point.Point at 0x7f3089265590>,
#  <shapely.geometry.point.Point at 0x7f3089265490>,
#  <shapely.geometry.point.Point at 0x7f3089265850>,
#  <shapely.geometry.point.Point at 0x7f3089265710>,
#  <shapely.geometry.point.Point at 0x7f3089265610>,
#  <shapely.geometry.point.Point at 0x7f30892659d0>,
#  <shapely.geometry.point.Point at 0x7f3089265890>,
#  <shapely.geometry.point.Point at 0x7f3089265790>,
#  <shapely.geometry.point.Point at 0x7f3089265b50>,
#  <shapely.geometry.point.Point at 0x7f3089265a10>,
#  <shapely.geometry.point.Point at 0x7f3089265910>,
#  <shapely.geometry.point.Point at 0x7f3089265cd0>,
#  <shapely.geometry.point.Point at 0x7f3089265b90>,
#  <shapely.geometry.point.Point at 0x7f3089265d50>,
#  <shapely.geometry.point.Point at 0x7f3089265d90>,
#  <shapely.geometry.point.Point at 0x7f3089265d10>,
#  <shapely.geometry.point.Point at 0x7f3089265a90>,
#  <shapely.geometry.point.Point at 0x7f3089265f50>,
#  <shapely.geometry.point.Point at 0x7f3089265e10>,
#  <shapely.geometry.point.Point at 0x7f3089265c10>,
#  <shapely.geometry.point.Point at 0x7f3089265f90>,
#  <shapely.geometry.point.Point at 0x7f3089265ed0>,
#  <shapely.geometry.point.Point at 0x7f3089265950>,
#  <shapely.geometry.point.Point at 0x7f30892658d0>,
#  <shapely.geometry.point.Point at 0x7f3089265e50>,
#  <shapely.geometry.point.Point at 0x7f3089265fd0>,
#  <shapely.geometry.point.Point at 0x7f3089265450>,
#  <shapely.geometry.point.Point at 0x7f30892657d0>,
#  <shapely.geometry.point.Point at 0x7f3089265ad0>,
#  <shapely.geometry.point.Point at 0x7f3089265350>,
#  <shapely.geometry.point.Point at 0x7f30892651d0>,
#  <shapely.geometry.point.Point at 0x7f30892655d0>,
#  <shapely.geometry.point.Point at 0x7f3089265bd0>,
#  <shapely.geometry.point.Point at 0x7f3089265a50>,
#  <shapely.geometry.point.Point at 0x7f3089281210>,
#  <shapely.geometry.point.Point at 0x7f3089281150>,
#  <shapely.geometry.point.Point at 0x7f3089281410>,
#  <shapely.geometry.point.Point at 0x7f3089281190>,
#  <shapely.geometry.point.Point at 0x7f30892812d0>,
#  <shapely.geometry.point.Point at 0x7f30892813d0>,
#  <shapely.geometry.point.Point at 0x7f3089281050>,
#  <shapely.geometry.point.Point at 0x7f3089281250>,
#  <shapely.geometry.point.Point at 0x7f3089281590>,
#  <shapely.geometry.point.Point at 0x7f3089281290>,
#  <shapely.geometry.point.Point at 0x7f3089281350>,
#  <shapely.geometry.point.Point at 0x7f30892817d0>,
#  <shapely.geometry.point.Point at 0x7f30892815d0>,
#  <shapely.geometry.point.Point at 0x7f30897b2910>,
#  <shapely.geometry.point.Point at 0x7f30897b2450>,
#  <shapely.geometry.point.Point at 0x7f30897b2bd0>,
#  <shapely.geometry.point.Point at 0x7f30897b2b10>,
#  <shapely.geometry.point.Point at 0x7f30897b2dd0>,
#  <shapely.geometry.point.Point at 0x7f30897d95d0>,
#  <shapely.geometry.point.Point at 0x7f30897b2e10>,
#  <shapely.geometry.point.Point at 0x7f308e045d90>,
#  <shapely.geometry.point.Point at 0x7f30897d9e10>,
#  <shapely.geometry.point.Point at 0x7f30c9f7c1d0>,
#  <shapely.geometry.point.Point at 0x7f3089ce94d0>,
#  <shapely.geometry.point.Point at 0x7f30c9f7ced0>,
#  <shapely.geometry.point.Point at 0x7f30c9f7ca90>,
#  <shapely.geometry.point.Point at 0x7f3089281710>,
#  <shapely.geometry.point.Point at 0x7f3089281850>,
#  <shapely.geometry.point.Point at 0x7f3089281790>,
#  <shapely.geometry.point.Point at 0x7f30892814d0>,
#  <shapely.geometry.point.Point at 0x7f3089281990>,
#  <shapely.geometry.point.Point at 0x7f3089281810>,
#  <shapely.geometry.point.Point at 0x7f3089281650>,
#  <shapely.geometry.point.Point at 0x7f3089281b10>,
#  <shapely.geometry.point.Point at 0x7f30892819d0>,
#  <shapely.geometry.point.Point at 0x7f30892818d0>,
#  <shapely.geometry.point.Point at 0x7f3089281c90>,
#  <shapely.geometry.point.Point at 0x7f3089281b50>,
#  <shapely.geometry.point.Point at 0x7f3089281a50>,
#  <shapely.geometry.point.Point at 0x7f3089281e10>,
#  <shapely.geometry.point.Point at 0x7f3089281cd0>,
#  <shapely.geometry.point.Point at 0x7f3089281bd0>,
#  <shapely.geometry.point.Point at 0x7f3089281f90>,
#  <shapely.geometry.point.Point at 0x7f3089281e50>,
#  <shapely.geometry.point.Point at 0x7f3089281d50>,
#  <shapely.geometry.point.Point at 0x7f3089281fd0>,
#  <shapely.geometry.point.Point at 0x7f3089281c10>,
#  <shapely.geometry.point.Point at 0x7f3089281b90>,
#  <shapely.geometry.point.Point at 0x7f3089281690>,
#  <shapely.geometry.point.Point at 0x7f3089281d90>,
#  <shapely.geometry.point.Point at 0x7f3089281510>,
#  <shapely.geometry.point.Point at 0x7f3089281390>,
#  <shapely.geometry.point.Point at 0x7f3089281890>,
#  <shapely.geometry.point.Point at 0x7f3089281110>,
#  <shapely.geometry.point.Point at 0x7f30892811d0>,
#  <shapely.geometry.point.Point at 0x7f3089281450>,
#  <shapely.geometry.point.Point at 0x7f3089281610>,
#  <shapely.geometry.point.Point at 0x7f30892810d0>,
#  <shapely.geometry.point.Point at 0x7f3089281310>,
#  <shapely.geometry.point.Point at 0x7f3089281f10>,
#  <shapely.geometry.point.Point at 0x7f3089281a90>,
#  <shapely.geometry.point.Point at 0x7f30892670d0>,
#  <shapely.geometry.point.Point at 0x7f3089267250>,
#  <shapely.geometry.point.Point at 0x7f3089267290>,
#  <shapely.geometry.point.Point at 0x7f3089267110>,
#  <shapely.geometry.point.Point at 0x7f3089267050>,
#  <shapely.geometry.point.Point at 0x7f3089267410>,
#  <shapely.geometry.point.Point at 0x7f30892672d0>,
#  <shapely.geometry.point.Point at 0x7f30892671d0>,
#  <shapely.geometry.point.Point at 0x7f3089267590>,
#  <shapely.geometry.point.Point at 0x7f3089267450>,
#  <shapely.geometry.point.Point at 0x7f3089267350>,
#  <shapely.geometry.point.Point at 0x7f3089267710>,
#  <shapely.geometry.point.Point at 0x7f30892675d0>,
#  <shapely.geometry.point.Point at 0x7f3089267790>,
#  <shapely.geometry.point.Point at 0x7f30892677d0>,
#  <shapely.geometry.point.Point at 0x7f3089267750>,
#  <shapely.geometry.point.Point at 0x7f3089267890>,
#  <shapely.geometry.point.Point at 0x7f30892678d0>,
#  <shapely.geometry.point.Point at 0x7f3089267850>,
#  <shapely.geometry.point.Point at 0x7f30892674d0>,
#  <shapely.geometry.point.Point at 0x7f3089267a90>,
#  <shapely.geometry.point.Point at 0x7f3089267950>,
#  <shapely.geometry.point.Point at 0x7f3089267650>,
#  <shapely.geometry.point.Point at 0x7f3089267c10>,
#  <shapely.geometry.point.Point at 0x7f3089267ad0>,
#  <shapely.geometry.point.Point at 0x7f3089267c90>,
#  <shapely.geometry.point.Point at 0x7f3089267cd0>,
#  <shapely.geometry.point.Point at 0x7f3089267c50>,
#  <shapely.geometry.point.Point at 0x7f30892679d0>,
#  <shapely.geometry.point.Point at 0x7f3089267e90>,
#  <shapely.geometry.point.Point at 0x7f3089267d50>,
#  <shapely.geometry.point.Point at 0x7f3089267fd0>,
#  <shapely.geometry.point.Point at 0x7f3089267dd0>,
#  <shapely.geometry.point.Point at 0x7f3089267ed0>,
#  <shapely.geometry.point.Point at 0x7f3089267f90>,
#  <shapely.geometry.point.Point at 0x7f3089267a10>,
#  <shapely.geometry.point.Point at 0x7f3089267990>,
#  <shapely.geometry.point.Point at 0x7f3089267f10>,
#  <shapely.geometry.point.Point at 0x7f3089267390>,
#  <shapely.geometry.point.Point at 0x7f3089267310>,
#  <shapely.geometry.point.Point at 0x7f3089267e10>,
#  <shapely.geometry.point.Point at 0x7f3089267b90>,
#  <shapely.geometry.point.Point at 0x7f3089267210>,
#  <shapely.geometry.point.Point at 0x7f3089267b10>,
#  <shapely.geometry.point.Point at 0x7f3089267610>,
#  <shapely.geometry.point.Point at 0x7f3089267d90>,
#  <shapely.geometry.point.Point at 0x7f3089267490>,
#  <shapely.geometry.point.Point at 0x7f3089267190>,
#  <shapely.geometry.point.Point at 0x7f3089259190>,
#  <shapely.geometry.point.Point at 0x7f3089259110>,
#  <shapely.geometry.point.Point at 0x7f3089259210>,
#  <shapely.geometry.point.Point at 0x7f3089259290>,
#  <shapely.geometry.point.Point at 0x7f3089259150>,
#  <shapely.geometry.point.Point at 0x7f3089259310>,
#  <shapely.geometry.point.Point at 0x7f3089259390>,
#  <shapely.geometry.point.Point at 0x7f3089259250>,
#  <shapely.geometry.point.Point at 0x7f3089259410>,
#  <shapely.geometry.point.Point at 0x7f3089259490>,
#  <shapely.geometry.point.Point at 0x7f3089259350>,
#  <shapely.geometry.point.Point at 0x7f3089259510>,
#  <shapely.geometry.point.Point at 0x7f3089259590>,
#  <shapely.geometry.point.Point at 0x7f3089259450>,
#  <shapely.geometry.point.Point at 0x7f3089259610>,
#  <shapely.geometry.point.Point at 0x7f3089259690>,
#  <shapely.geometry.point.Point at 0x7f3089259550>,
#  <shapely.geometry.point.Point at 0x7f3089259710>,
#  <shapely.geometry.point.Point at 0x7f3089259790>,
#  <shapely.geometry.point.Point at 0x7f3089259650>,
#  <shapely.geometry.point.Point at 0x7f3089259810>,
#  <shapely.geometry.point.Point at 0x7f3089259890>,
#  <shapely.geometry.point.Point at 0x7f3089259750>,
#  <shapely.geometry.point.Point at 0x7f3089259910>,
#  <shapely.geometry.point.Point at 0x7f3089259090>,
#  <shapely.geometry.point.Point at 0x7f3089259850>,
#  <shapely.geometry.point.Point at 0x7f3089259a10>,
#  <shapely.geometry.point.Point at 0x7f3089259a50>,
#  <shapely.geometry.point.Point at 0x7f30892597d0>,
#  <shapely.geometry.point.Point at 0x7f3089259b90>,
#  <shapely.geometry.point.Point at 0x7f3089259bd0>,
#  <shapely.geometry.point.Point at 0x7f30892598d0>,
#  <shapely.geometry.point.Point at 0x7f3089259990>,
#  <shapely.geometry.point.Point at 0x7f3089259d50>,
#  <shapely.geometry.point.Point at 0x7f3089259c10>,
#  <shapely.geometry.point.Point at 0x7f3089259b10>,
#  <shapely.geometry.point.Point at 0x7f3089259ed0>,
#  <shapely.geometry.point.Point at 0x7f3089259d90>,
#  <shapely.geometry.point.Point at 0x7f3089259c90>,
#  <shapely.geometry.point.Point at 0x7f3089259f10>,
#  <shapely.geometry.point.Point at 0x7f3089259c50>,
#  <shapely.geometry.point.Point at 0x7f3089259e50>,
#  <shapely.geometry.point.Point at 0x7f3089259ad0>,
#  <shapely.geometry.point.Point at 0x7f3089259dd0>,
#  <shapely.geometry.point.Point at 0x7f3089259950>,
#  <shapely.geometry.point.Point at 0x7f3089259f50>,
#  <shapely.geometry.point.Point at 0x7f3089259b50>,
#  <shapely.geometry.point.Point at 0x7f3089264090>,
#  <shapely.geometry.point.Point at 0x7f30892640d0>,
#  <shapely.geometry.point.Point at 0x7f3089264050>,
#  <shapely.geometry.point.Point at 0x7f3089264190>,
#  <shapely.geometry.point.Point at 0x7f30892641d0>,
#  <shapely.geometry.point.Point at 0x7f3089264150>,
#  <shapely.geometry.point.Point at 0x7f3089264350>,
#  <shapely.geometry.point.Point at 0x7f3089264390>,
#  <shapely.geometry.point.Point at 0x7f3089264210>,
#  <shapely.geometry.point.Point at 0x7f30892644d0>,
#  <shapely.geometry.point.Point at 0x7f3089264510>,
#  <shapely.geometry.point.Point at 0x7f3089264250>,
#  <shapely.geometry.point.Point at 0x7f30892642d0>,
#  <shapely.geometry.point.Point at 0x7f3089264690>,
#  <shapely.geometry.point.Point at 0x7f3089264550>,
#  <shapely.geometry.point.Point at 0x7f3089264710>,
#  <shapely.geometry.point.Point at 0x7f3089264750>,
#  <shapely.geometry.point.Point at 0x7f30892646d0>,
#  <shapely.geometry.point.Point at 0x7f3089264450>,
#  <shapely.geometry.point.Point at 0x7f3089264910>,
#  <shapely.geometry.point.Point at 0x7f30892647d0>,
#  <shapely.geometry.point.Point at 0x7f30892645d0>,
#  <shapely.geometry.point.Point at 0x7f3089264a90>,
#  <shapely.geometry.point.Point at 0x7f3089264950>,
#  <shapely.geometry.point.Point at 0x7f3089264850>,
#  <shapely.geometry.point.Point at 0x7f3089264c10>,
#  <shapely.geometry.point.Point at 0x7f3089264ad0>,
#  <shapely.geometry.point.Point at 0x7f3089264c90>,
#  <shapely.geometry.point.Point at 0x7f3089264cd0>,
#  <shapely.geometry.point.Point at 0x7f3089264c50>,
#  <shapely.geometry.point.Point at 0x7f30892649d0>,
#  <shapely.geometry.point.Point at 0x7f3089264d50>,
#  <shapely.geometry.point.Point at 0x7f3089264990>,
#  <shapely.geometry.point.Point at 0x7f3089264890>,
#  <shapely.geometry.point.Point at 0x7f3089264e10>,
#  <shapely.geometry.point.Point at 0x7f3089264b50>,
#  <shapely.geometry.point.Point at 0x7f3089264310>,
#  <shapely.geometry.point.Point at 0x7f3089264810>,
#  <shapely.geometry.point.Point at 0x7f3089264b10>,
#  <shapely.geometry.point.Point at 0x7f3089264f50>,
#  <shapely.geometry.point.Point at 0x7f3089264290>,
#  <shapely.geometry.point.Point at 0x7f3089264fd0>,
#  <shapely.geometry.point.Point at 0x7f3089264e90>,
#  <shapely.geometry.point.Point at 0x7f3089264490>,
#  <shapely.geometry.point.Point at 0x7f3089264ed0>,
#  <shapely.geometry.point.Point at 0x7f3089264dd0>,
#  <shapely.geometry.point.Point at 0x7f3089264610>,
#  <shapely.geometry.point.Point at 0x7f3089264a10>,
#  <shapely.geometry.point.Point at 0x7f308926d110>,
#  <shapely.geometry.point.Point at 0x7f308926d290>,
#  <shapely.geometry.point.Point at 0x7f308926d2d0>,
#  <shapely.geometry.point.Point at 0x7f308926d150>,
#  <shapely.geometry.point.Point at 0x7f308926d090>,
#  <shapely.geometry.point.Point at 0x7f308926d450>,
#  <shapely.geometry.point.Point at 0x7f308926d310>,
#  <shapely.geometry.point.Point at 0x7f308926d210>,
#  <shapely.geometry.point.Point at 0x7f308926d5d0>,
#  <shapely.geometry.point.Point at 0x7f308926d490>,
#  <shapely.geometry.point.Point at 0x7f308926d390>,
#  <shapely.geometry.point.Point at 0x7f308926d750>,
#  <shapely.geometry.point.Point at 0x7f308926d610>,
#  <shapely.geometry.point.Point at 0x7f308926d510>,
#  <shapely.geometry.point.Point at 0x7f308926d8d0>,
#  <shapely.geometry.point.Point at 0x7f308926d790>,
#  <shapely.geometry.point.Point at 0x7f308926d690>,
#  <shapely.geometry.point.Point at 0x7f308926da50>,
#  <shapely.geometry.point.Point at 0x7f308926d910>,
#  <shapely.geometry.point.Point at 0x7f308926d810>,
#  <shapely.geometry.point.Point at 0x7f308926dbd0>,
#  <shapely.geometry.point.Point at 0x7f308926da90>,
#  <shapely.geometry.point.Point at 0x7f308926d990>,
#  <shapely.geometry.point.Point at 0x7f308926dd50>,
#  <shapely.geometry.point.Point at 0x7f308926dc10>,
#  <shapely.geometry.point.Point at 0x7f308926db10>,
#  <shapely.geometry.point.Point at 0x7f308926ded0>,
#  <shapely.geometry.point.Point at 0x7f308926dd90>,
#  <shapely.geometry.point.Point at 0x7f308926dc90>,
#  <shapely.geometry.point.Point at 0x7f308926df10>,
#  <shapely.geometry.point.Point at 0x7f308926dfd0>,
#  <shapely.geometry.point.Point at 0x7f308926db50>,
#  <shapely.geometry.point.Point at 0x7f308926dad0>,
#  <shapely.geometry.point.Point at 0x7f308926df50>,
#  <shapely.geometry.point.Point at 0x7f308926d6d0>,
#  <shapely.geometry.point.Point at 0x7f308926d650>,
#  <shapely.geometry.point.Point at 0x7f308926de50>,
#  <shapely.geometry.point.Point at 0x7f308926dcd0>,
#  <shapely.geometry.point.Point at 0x7f308926d1d0>,
#  <shapely.geometry.point.Point at 0x7f308926d550>,
#  <shapely.geometry.point.Point at 0x7f308926d0d0>,
#  <shapely.geometry.point.Point at 0x7f308926d850>,
#  <shapely.geometry.point.Point at 0x7f308926d3d0>,
#  <shapely.geometry.point.Point at 0x7f308926d7d0>,
#  <shapely.geometry.point.Point at 0x7f308926d950>,
#  <shapely.geometry.point.Point at 0x7f308926dc50>,
#  <shapely.geometry.point.Point at 0x7f3088671110>,
#  <shapely.geometry.point.Point at 0x7f3088671290>,
#  <shapely.geometry.point.Point at 0x7f30886712d0>,
#  <shapely.geometry.point.Point at 0x7f3088671150>,
#  <shapely.geometry.point.Point at 0x7f3088671350>,
#  <shapely.geometry.point.Point at 0x7f3088671390>,
#  <shapely.geometry.point.Point at 0x7f3088671310>,
#  <shapely.geometry.point.Point at 0x7f3088671090>,
#  <shapely.geometry.point.Point at 0x7f3088671550>,
#  <shapely.geometry.point.Point at 0x7f3088671410>,
#  <shapely.geometry.point.Point at 0x7f3088671210>,
#  <shapely.geometry.point.Point at 0x7f30886716d0>,
#  <shapely.geometry.point.Point at 0x7f3088671590>,
#  <shapely.geometry.point.Point at 0x7f3088671490>,
#  <shapely.geometry.point.Point at 0x7f3088671850>,
#  <shapely.geometry.point.Point at 0x7f3088671710>,
#  <shapely.geometry.point.Point at 0x7f30886718d0>,
#  <shapely.geometry.point.Point at 0x7f3088671910>,
#  <shapely.geometry.point.Point at 0x7f3088671890>,
#  <shapely.geometry.point.Point at 0x7f3088671610>,
#  <shapely.geometry.point.Point at 0x7f3088671ad0>,
#  <shapely.geometry.point.Point at 0x7f3088671990>,
#  <shapely.geometry.point.Point at 0x7f3088671790>,
#  <shapely.geometry.point.Point at 0x7f3088671c50>,
#  <shapely.geometry.point.Point at 0x7f3088671b10>,
#  <shapely.geometry.point.Point at 0x7f3088671a10>,
#  <shapely.geometry.point.Point at 0x7f3088671dd0>,
#  <shapely.geometry.point.Point at 0x7f3088671c90>,
#  <shapely.geometry.point.Point at 0x7f3088671b90>,
#  <shapely.geometry.point.Point at 0x7f3088671f50>,
#  <shapely.geometry.point.Point at 0x7f3088671e10>,
#  <shapely.geometry.point.Point at 0x7f3088671d10>,
#  <shapely.geometry.point.Point at 0x7f3088671f90>,
#  <shapely.geometry.point.Point at 0x7f3088671ed0>,
#  <shapely.geometry.point.Point at 0x7f3088671fd0>,
#  <shapely.geometry.point.Point at 0x7f3088671e50>,
#  <shapely.geometry.point.Point at 0x7f3088671bd0>,
#  <shapely.geometry.point.Point at 0x7f3088671d50>,
#  <shapely.geometry.point.Point at 0x7f3088671650>,
#  <shapely.geometry.point.Point at 0x7f30886714d0>,
#  <shapely.geometry.point.Point at 0x7f3088671b50>,
#  <shapely.geometry.point.Point at 0x7f3088671050>,
#  <shapely.geometry.point.Point at 0x7f3088671450>,
#  <shapely.geometry.point.Point at 0x7f30886719d0>,
#  <shapely.geometry.point.Point at 0x7f308926f190>,
#  <shapely.geometry.point.Point at 0x7f308926f1d0>,
#  <shapely.geometry.point.Point at 0x7f308926f050>,
#  <shapely.geometry.point.Point at 0x7f308926f290>,
#  <shapely.geometry.point.Point at 0x7f308926f2d0>,
#  <shapely.geometry.point.Point at 0x7f308926f250>,
#  <shapely.geometry.point.Point at 0x7f308926f410>,
#  <shapely.geometry.point.Point at 0x7f308926f4d0>,
#  <shapely.geometry.point.Point at 0x7f308926f110>,
#  <shapely.geometry.point.Point at 0x7f308926f310>,
#  <shapely.geometry.point.Point at 0x7f308926f210>,
#  <shapely.geometry.point.Point at 0x7f308926f650>,
#  <shapely.geometry.point.Point at 0x7f308926f510>,
#  <shapely.geometry.point.Point at 0x7f308926f490>,
#  <shapely.geometry.point.Point at 0x7f308926f7d0>,
#  <shapely.geometry.point.Point at 0x7f308926f690>,
#  <shapely.geometry.point.Point at 0x7f308926f590>,
#  <shapely.geometry.point.Point at 0x7f308926fa10>,
#  <shapely.geometry.point.Point at 0x7f308926f810>,
#  <shapely.geometry.point.Point at 0x7f308926fa90>,
#  <shapely.geometry.point.Point at 0x7f308926fb10>,
#  <shapely.geometry.point.Point at 0x7f308926f9d0>,
#  <shapely.geometry.point.Point at 0x7f308926fb90>,
#  <shapely.geometry.point.Point at 0x7f308926f950>,
#  <shapely.geometry.point.Point at 0x7f308926fad0>,
#  <shapely.geometry.point.Point at 0x7f308926fbd0>,
#  <shapely.geometry.point.Point at 0x7f308926fc10>,
#  <shapely.geometry.point.Point at 0x7f308926fb50>,
#  <shapely.geometry.point.Point at 0x7f308926fcd0>,
#  <shapely.geometry.point.Point at 0x7f308926fe10>,
#  <shapely.geometry.point.Point at 0x7f308926fc90>,
#  <shapely.geometry.point.Point at 0x7f308926fe90>,
#  <shapely.geometry.point.Point at 0x7f308926fd10>,
#  <shapely.geometry.point.Point at 0x7f308926fdd0>,
#  <shapely.geometry.point.Point at 0x7f308926fed0>,
#  <shapely.geometry.point.Point at 0x7f308926ff10>,
#  <shapely.geometry.point.Point at 0x7f308926fe50>,
#  <shapely.geometry.point.Point at 0x7f308926ff90>,
#  <shapely.geometry.point.Point at 0x7f308926ffd0>,
#  <shapely.geometry.point.Point at 0x7f308926f750>,
#  <shapely.geometry.point.Point at 0x7f308926f5d0>,
#  <shapely.geometry.point.Point at 0x7f308926f550>,
#  <shapely.geometry.point.Point at 0x7f308926f0d0>,
#  <shapely.geometry.point.Point at 0x7f308926f350>,
#  <shapely.geometry.point.Point at 0x7f308926f8d0>,
#  <shapely.geometry.point.Point at 0x7f308926f390>,
#  <shapely.geometry.point.Point at 0x7f308926f090>,
#  <shapely.geometry.point.Point at 0x7f308926f850>,
#  <shapely.geometry.point.Point at 0x7f3088679190>,
#  <shapely.geometry.point.Point at 0x7f3088679150>,
#  <shapely.geometry.point.Point at 0x7f3088679210>,
#  <shapely.geometry.point.Point at 0x7f3088679250>,
#  <shapely.geometry.point.Point at 0x7f30886791d0>,
#  <shapely.geometry.point.Point at 0x7f3088679310>,
#  <shapely.geometry.point.Point at 0x7f3088679350>,
#  <shapely.geometry.point.Point at 0x7f30886792d0>,
#  <shapely.geometry.point.Point at 0x7f30886794d0>,
#  <shapely.geometry.point.Point at 0x7f3088679510>,
#  <shapely.geometry.point.Point at 0x7f3088679390>,
#  <shapely.geometry.point.Point at 0x7f3088679590>,
#  <shapely.geometry.point.Point at 0x7f30886795d0>,
#  <shapely.geometry.point.Point at 0x7f3088679550>,
#  <shapely.geometry.point.Point at 0x7f30886790d0>,
#  <shapely.geometry.point.Point at 0x7f3088679790>,
#  <shapely.geometry.point.Point at 0x7f3088679650>,
#  <shapely.geometry.point.Point at 0x7f3088679450>,
#  <shapely.geometry.point.Point at 0x7f3088679910>,
#  <shapely.geometry.point.Point at 0x7f30886797d0>,
#  <shapely.geometry.point.Point at 0x7f3088679990>,
#  <shapely.geometry.point.Point at 0x7f30886799d0>,
#  <shapely.geometry.point.Point at 0x7f3088679950>,
#  <shapely.geometry.point.Point at 0x7f30886796d0>,
#  <shapely.geometry.point.Point at 0x7f3088679b90>,
#  <shapely.geometry.point.Point at 0x7f3088679a50>,
#  <shapely.geometry.point.Point at 0x7f3088679850>,
#  <shapely.geometry.point.Point at 0x7f3088679d10>,
#  <shapely.geometry.point.Point at 0x7f3088679bd0>,
#  <shapely.geometry.point.Point at 0x7f3088679ad0>,
#  <shapely.geometry.point.Point at 0x7f3088679e90>,
#  <shapely.geometry.point.Point at 0x7f3088679d50>,
#  <shapely.geometry.point.Point at 0x7f3088679f10>,
#  <shapely.geometry.point.Point at 0x7f3088679f50>,
#  <shapely.geometry.point.Point at 0x7f3088679ed0>,
#  <shapely.geometry.point.Point at 0x7f3088679fd0>,
#  <shapely.geometry.point.Point at 0x7f3088679d90>,
#  <shapely.geometry.point.Point at 0x7f3088679e10>,
#  <shapely.geometry.point.Point at 0x7f3088679c90>,
#  <shapely.geometry.point.Point at 0x7f3088679a90>,
#  <shapely.geometry.point.Point at 0x7f3088679c10>,
#  <shapely.geometry.point.Point at 0x7f3088679810>,
#  <shapely.geometry.point.Point at 0x7f3088679710>,
#  <shapely.geometry.point.Point at 0x7f3088679490>,
#  <shapely.geometry.point.Point at 0x7f3088679890>,
#  <shapely.geometry.point.Point at 0x7f308926e150>,
#  <shapely.geometry.point.Point at 0x7f308926e1d0>,
#  <shapely.geometry.point.Point at 0x7f308926e250>,
#  <shapely.geometry.point.Point at 0x7f308926e110>,
#  <shapely.geometry.point.Point at 0x7f308926e2d0>,
#  <shapely.geometry.point.Point at 0x7f308926e350>,
#  <shapely.geometry.point.Point at 0x7f308926e210>,
#  <shapely.geometry.point.Point at 0x7f308926e3d0>,
#  <shapely.geometry.point.Point at 0x7f308926e450>,
#  <shapely.geometry.point.Point at 0x7f308926e310>,
#  <shapely.geometry.point.Point at 0x7f308926e4d0>,
#  <shapely.geometry.point.Point at 0x7f308926e550>,
#  <shapely.geometry.point.Point at 0x7f308926e410>,
#  <shapely.geometry.point.Point at 0x7f308926e5d0>,
#  <shapely.geometry.point.Point at 0x7f308926e650>,
#  <shapely.geometry.point.Point at 0x7f308926e510>,
#  <shapely.geometry.point.Point at 0x7f308926e6d0>,
#  <shapely.geometry.point.Point at 0x7f308926e0d0>,
#  <shapely.geometry.point.Point at 0x7f308926e610>,
#  <shapely.geometry.point.Point at 0x7f308926e7d0>,
#  <shapely.geometry.point.Point at 0x7f308926e8d0>,
#  <shapely.geometry.point.Point at 0x7f308926e590>,
#  <shapely.geometry.point.Point at 0x7f308926e950>,
#  <shapely.geometry.point.Point at 0x7f308926e810>,
#  <shapely.geometry.point.Point at 0x7f308926e890>,
#  <shapely.geometry.point.Point at 0x7f308926ea50>,
#  <shapely.geometry.point.Point at 0x7f308926ea90>,
#  <shapely.geometry.point.Point at 0x7f308926e850>,
#  <shapely.geometry.point.Point at 0x7f308926e750>,
#  <shapely.geometry.point.Point at 0x7f308926ecd0>,
#  <shapely.geometry.point.Point at 0x7f308926ead0>,
#  <shapely.geometry.point.Point at 0x7f308926ed50>,
#  <shapely.geometry.point.Point at 0x7f308926edd0>,
#  <shapely.geometry.point.Point at 0x7f308926ec90>,
#  <shapely.geometry.point.Point at 0x7f308926ee50>,
#  <shapely.geometry.point.Point at 0x7f308926ec10>,
#  <shapely.geometry.point.Point at 0x7f308926ed90>,
#  <shapely.geometry.point.Point at 0x7f308926e9d0>,
#  <shapely.geometry.point.Point at 0x7f308926ef90>,
#  <shapely.geometry.point.Point at 0x7f308926ee10>,
#  <shapely.geometry.point.Point at 0x7f308926efd0>,
#  <shapely.geometry.point.Point at 0x7f308926e990>,
#  <shapely.geometry.point.Point at 0x7f308926ea10>,
#  <shapely.geometry.point.Point at 0x7f308926e790>,
#  <shapely.geometry.point.Point at 0x7f308926ef10>,
#  <shapely.geometry.point.Point at 0x7f308926eb90>,
#  <shapely.geometry.point.Point at 0x7f308926ee90>,
#  <shapely.geometry.point.Point at 0x7f308926eb10>,
#  <shapely.geometry.point.Point at 0x7f308925b810>,
#  <shapely.geometry.point.Point at 0x7f308925b890>,
#  <shapely.geometry.point.Point at 0x7f308925b050>,
#  <shapely.geometry.point.Point at 0x7f308925b1d0>,
#  <shapely.geometry.point.Point at 0x7f308925b210>,
#  <shapely.geometry.point.Point at 0x7f308925b090>,
#  <shapely.geometry.point.Point at 0x7f308925b350>,
#  <shapely.geometry.point.Point at 0x7f308925b390>,
#  <shapely.geometry.point.Point at 0x7f308925b0d0>,
#  <shapely.geometry.point.Point at 0x7f308925b410>,
#  <shapely.geometry.point.Point at 0x7f308925b450>,
#  <shapely.geometry.point.Point at 0x7f308925b3d0>,
#  <shapely.geometry.point.Point at 0x7f308925b150>,
#  <shapely.geometry.point.Point at 0x7f308925b610>,
#  <shapely.geometry.point.Point at 0x7f308925b4d0>,
#  <shapely.geometry.point.Point at 0x7f308925b2d0>,
#  <shapely.geometry.point.Point at 0x7f308925b6d0>,
#  <shapely.geometry.point.Point at 0x7f308925b710>,
#  <shapely.geometry.point.Point at 0x7f308925b650>,
#  <shapely.geometry.point.Point at 0x7f308925b290>,
#  <shapely.geometry.point.Point at 0x7f308925b190>,
#  <shapely.geometry.point.Point at 0x7f308925b750>,
#  <shapely.geometry.point.Point at 0x7f308925b850>,
#  <shapely.geometry.point.Point at 0x7f308925b8d0>,
#  <shapely.geometry.point.Point at 0x7f308925b110>,
#  <shapely.geometry.point.Point at 0x7f308925b7d0>,
#  <shapely.geometry.point.Point at 0x7f308925ba90>,
#  <shapely.geometry.point.Point at 0x7f308925b950>,
#  <shapely.geometry.point.Point at 0x7f308925b510>,
#  <shapely.geometry.point.Point at 0x7f308925bc10>,
#  <shapely.geometry.point.Point at 0x7f308925bad0>,
#  <shapely.geometry.point.Point at 0x7f308925b9d0>,
#  <shapely.geometry.point.Point at 0x7f308925bd90>,
#  <shapely.geometry.point.Point at 0x7f308925bc50>,
#  <shapely.geometry.point.Point at 0x7f308925bb50>,
#  <shapely.geometry.point.Point at 0x7f308925bf10>,
#  <shapely.geometry.point.Point at 0x7f308925bdd0>,
#  <shapely.geometry.point.Point at 0x7f308925bcd0>,
#  <shapely.geometry.point.Point at 0x7f308925bf50>,
#  <shapely.geometry.point.Point at 0x7f308925bf90>,
#  <shapely.geometry.point.Point at 0x7f308925bb10>,
#  <shapely.geometry.point.Point at 0x7f308925ba10>,
#  <shapely.geometry.point.Point at 0x7f308925be90>,
#  <shapely.geometry.point.Point at 0x7f308925bfd0>,
#  <shapely.geometry.point.Point at 0x7f308925b790>,
#  <shapely.geometry.point.Point at 0x7f308925be10>,
#  <shapely.geometry.point.Point at 0x7f308925bc90>,
#  <shapely.geometry.point.Point at 0x7f308925b590>,
#  <shapely.geometry.point.Point at 0x7f308925b990>,
#  <shapely.geometry.point.Point at 0x7f308925bd10>,
#  <shapely.geometry.point.Point at 0x7f308925bb90>,
#  <shapely.geometry.point.Point at 0x7f3089284190>,
#  <shapely.geometry.point.Point at 0x7f30892841d0>,
#  <shapely.geometry.point.Point at 0x7f3089284050>,
#  <shapely.geometry.point.Point at 0x7f3089284310>,
#  <shapely.geometry.point.Point at 0x7f3089284350>,
#  <shapely.geometry.point.Point at 0x7f3089284090>,
#  <shapely.geometry.point.Point at 0x7f30892843d0>,
#  <shapely.geometry.point.Point at 0x7f3089284410>,
#  <shapely.geometry.point.Point at 0x7f3089284390>,
#  <shapely.geometry.point.Point at 0x7f3089284110>,
#  <shapely.geometry.point.Point at 0x7f30892845d0>,
#  <shapely.geometry.point.Point at 0x7f3089284490>,
#  <shapely.geometry.point.Point at 0x7f3089284290>,
#  <shapely.geometry.point.Point at 0x7f3089284750>,
#  <shapely.geometry.point.Point at 0x7f3089284610>,
#  <shapely.geometry.point.Point at 0x7f3089284510>,
#  <shapely.geometry.point.Point at 0x7f30892848d0>,
#  <shapely.geometry.point.Point at 0x7f3089284790>,
#  <shapely.geometry.point.Point at 0x7f3089284690>,
#  <shapely.geometry.point.Point at 0x7f3089284a50>,
#  <shapely.geometry.point.Point at 0x7f3089284910>,
#  <shapely.geometry.point.Point at 0x7f3089284ad0>,
#  <shapely.geometry.point.Point at 0x7f3089284b10>,
#  <shapely.geometry.point.Point at 0x7f3089284a90>,
#  <shapely.geometry.point.Point at 0x7f3089284810>,
#  <shapely.geometry.point.Point at 0x7f3089284cd0>,
#  <shapely.geometry.point.Point at 0x7f3089284b90>,
#  <shapely.geometry.point.Point at 0x7f3089284990>,
#  <shapely.geometry.point.Point at 0x7f3089284e50>,
#  <shapely.geometry.point.Point at 0x7f3089284d10>,
#  <shapely.geometry.point.Point at 0x7f3089284ed0>,
#  <shapely.geometry.point.Point at 0x7f3089284f10>,
#  <shapely.geometry.point.Point at 0x7f3089284e90>,
#  <shapely.geometry.point.Point at 0x7f3089284c10>,
#  <shapely.geometry.point.Point at 0x7f3089284fd0>,
#  <shapely.geometry.point.Point at 0x7f3089284f90>,
#  <shapely.geometry.point.Point at 0x7f3089284dd0>,
#  <shapely.geometry.point.Point at 0x7f3089284bd0>,
#  <shapely.geometry.point.Point at 0x7f3089284d50>,
#  <shapely.geometry.point.Point at 0x7f3089284650>,
#  <shapely.geometry.point.Point at 0x7f30892844d0>,
#  <shapely.geometry.point.Point at 0x7f30892849d0>,
#  <shapely.geometry.point.Point at 0x7f30892846d0>,
#  <shapely.geometry.point.Point at 0x7f3089284250>,
#  <shapely.geometry.point.Point at 0x7f30892842d0>,
#  <shapely.geometry.point.Point at 0x7f3088663090>,
#  <shapely.geometry.point.Point at 0x7f3088663210>,
#  <shapely.geometry.point.Point at 0x7f3088663250>,
#  <shapely.geometry.point.Point at 0x7f30886630d0>,
#  <shapely.geometry.point.Point at 0x7f30886632d0>,
#  <shapely.geometry.point.Point at 0x7f3088663310>,
#  <shapely.geometry.point.Point at 0x7f3088663290>,
#  <shapely.geometry.point.Point at 0x7f3088663050>,
#  <shapely.geometry.point.Point at 0x7f30886634d0>,
#  <shapely.geometry.point.Point at 0x7f3088663390>,
#  <shapely.geometry.point.Point at 0x7f3088663190>,
#  <shapely.geometry.point.Point at 0x7f3088663650>,
#  <shapely.geometry.point.Point at 0x7f3088663510>,
#  <shapely.geometry.point.Point at 0x7f3088663410>,
#  <shapely.geometry.point.Point at 0x7f30886637d0>,
#  <shapely.geometry.point.Point at 0x7f3088663690>,
#  <shapely.geometry.point.Point at 0x7f3088663590>,
#  <shapely.geometry.point.Point at 0x7f3088663950>,
#  <shapely.geometry.point.Point at 0x7f3088663810>,
#  <shapely.geometry.point.Point at 0x7f3088663710>,
#  <shapely.geometry.point.Point at 0x7f3088663ad0>,
#  <shapely.geometry.point.Point at 0x7f3088663990>,
#  <shapely.geometry.point.Point at 0x7f3088663890>,
#  <shapely.geometry.point.Point at 0x7f3088663c50>,
#  <shapely.geometry.point.Point at 0x7f3088663b10>,
#  <shapely.geometry.point.Point at 0x7f3088663a10>,
#  <shapely.geometry.point.Point at 0x7f3088663dd0>,
#  <shapely.geometry.point.Point at 0x7f3088663c90>,
#  <shapely.geometry.point.Point at 0x7f3088663b90>,
#  <shapely.geometry.point.Point at 0x7f3088663f50>,
#  <shapely.geometry.point.Point at 0x7f3088663e10>,
#  <shapely.geometry.point.Point at 0x7f3088663fd0>,
#  <shapely.geometry.point.Point at 0x7f3088663f90>,
#  <shapely.geometry.point.Point at 0x7f3088663e50>,
#  <shapely.geometry.point.Point at 0x7f30886639d0>,
#  <shapely.geometry.point.Point at 0x7f30886638d0>,
#  <shapely.geometry.point.Point at 0x7f3088663d50>,
#  <shapely.geometry.point.Point at 0x7f3088663ed0>,
#  <shapely.geometry.point.Point at 0x7f3088663450>,
#  <shapely.geometry.point.Point at 0x7f3088663850>,
#  <shapely.geometry.point.Point at 0x7f3088663b50>,
#  <shapely.geometry.point.Point at 0x7f30886633d0>,
#  <shapely.geometry.point.Point at 0x7f3088663bd0>,
#  <shapely.geometry.point.Point at 0x7f3088663a50>,
#  <shapely.geometry.point.Point at 0x7f3088663150>,
#  <shapely.geometry.point.Point at 0x7f30886635d0>,
#  <shapely.geometry.point.Point at 0x7f3088663750>,
#  <shapely.geometry.point.Point at 0x7f30886631d0>,
#  <shapely.geometry.point.Point at 0x7f308866f090>,
#  <shapely.geometry.point.Point at 0x7f308866f110>,
#  <shapely.geometry.point.Point at 0x7f308866f150>,
#  <shapely.geometry.point.Point at 0x7f308866f0d0>,
#  <shapely.geometry.point.Point at 0x7f308866f2d0>,
#  <shapely.geometry.point.Point at 0x7f308866f310>,
#  <shapely.geometry.point.Point at 0x7f308866f190>,
#  <shapely.geometry.point.Point at 0x7f308866f390>,
#  <shapely.geometry.point.Point at 0x7f308866f3d0>,
#  <shapely.geometry.point.Point at 0x7f308866f350>,
#  <shapely.geometry.point.Point at 0x7f308866f550>,
#  <shapely.geometry.point.Point at 0x7f308866f590>,
#  <shapely.geometry.point.Point at 0x7f308866f410>,
#  <shapely.geometry.point.Point at 0x7f308866f250>,
#  <shapely.geometry.point.Point at 0x7f308866f710>,
#  <shapely.geometry.point.Point at 0x7f308866f5d0>,
#  <shapely.geometry.point.Point at 0x7f308866f4d0>,
#  <shapely.geometry.point.Point at 0x7f308866fa10>,
#  <shapely.geometry.point.Point at 0x7f308866f750>,
#  <shapely.geometry.point.Point at 0x7f308866fa50>,
#  <shapely.geometry.point.Point at 0x7f308866fad0>,
#  <shapely.geometry.point.Point at 0x7f308866f650>,
#  <shapely.geometry.point.Point at 0x7f308866fb50>,
#  <shapely.geometry.point.Point at 0x7f308866f890>,
#  <shapely.geometry.point.Point at 0x7f308866fa90>,
#  <shapely.geometry.point.Point at 0x7f308866f7d0>,
#  <shapely.geometry.point.Point at 0x7f308866fc90>,
#  <shapely.geometry.point.Point at 0x7f308866fb10>,
#  <shapely.geometry.point.Point at 0x7f308866f950>,
#  <shapely.geometry.point.Point at 0x7f308866fe10>,
#  <shapely.geometry.point.Point at 0x7f308866fcd0>,
#  <shapely.geometry.point.Point at 0x7f308866fbd0>,
#  <shapely.geometry.point.Point at 0x7f308866ff90>,
#  <shapely.geometry.point.Point at 0x7f308866fe50>,
#  <shapely.geometry.point.Point at 0x7f308866fd50>,
#  <shapely.geometry.point.Point at 0x7f308866ffd0>,
#  <shapely.geometry.point.Point at 0x7f308866fb90>,
#  <shapely.geometry.point.Point at 0x7f308866f990>,
#  <shapely.geometry.point.Point at 0x7f308866ff10>,
#  <shapely.geometry.point.Point at 0x7f308866f610>,
#  <shapely.geometry.point.Point at 0x7f308866f510>,
#  <shapely.geometry.point.Point at 0x7f308866fe90>,
#  <shapely.geometry.point.Point at 0x7f308866fd10>,
#  <shapely.geometry.point.Point at 0x7f308866f490>,
#  <shapely.geometry.point.Point at 0x7f308866fc10>,
#  <shapely.geometry.point.Point at 0x7f308866f210>,
#  <shapely.geometry.point.Point at 0x7f308866fd90>,
#  <shapely.geometry.point.Point at 0x7f308866f290>,
#  <shapely.geometry.point.Point at 0x7f308866f810>,
#  <shapely.geometry.point.Point at 0x7f308867e090>,
#  <shapely.geometry.point.Point at 0x7f308867e050>,
#  <shapely.geometry.point.Point at 0x7f308867e150>,
#  <shapely.geometry.point.Point at 0x7f308867e190>,
#  <shapely.geometry.point.Point at 0x7f308867e110>,
#  <shapely.geometry.point.Point at 0x7f308867e310>,
#  <shapely.geometry.point.Point at 0x7f308867e350>,
#  <shapely.geometry.point.Point at 0x7f308867e1d0>,
#  <shapely.geometry.point.Point at 0x7f308867e3d0>,
#  <shapely.geometry.point.Point at 0x7f308867e410>,
#  <shapely.geometry.point.Point at 0x7f308867e390>,
#  <shapely.geometry.point.Point at 0x7f308867e590>,
#  <shapely.geometry.point.Point at 0x7f308867e510>,
#  <shapely.geometry.point.Point at 0x7f308867e4d0>,
#  <shapely.geometry.point.Point at 0x7f308867e2d0>,
#  <shapely.geometry.point.Point at 0x7f308867e690>,
#  <shapely.geometry.point.Point at 0x7f308867e710>,
#  <shapely.geometry.point.Point at 0x7f308867e750>,
#  <shapely.geometry.point.Point at 0x7f308867e450>,
#  <shapely.geometry.point.Point at 0x7f308867e7d0>,
#  <shapely.geometry.point.Point at 0x7f308867e810>,
#  <shapely.geometry.point.Point at 0x7f308867e790>,
#  <shapely.geometry.point.Point at 0x7f308867e650>,
#  <shapely.geometry.point.Point at 0x7f308867e9d0>,
#  <shapely.geometry.point.Point at 0x7f308867e890>,
#  <shapely.geometry.point.Point at 0x7f308867e290>,
#  <shapely.geometry.point.Point at 0x7f308867eb50>,
#  <shapely.geometry.point.Point at 0x7f308867ea10>,
#  <shapely.geometry.point.Point at 0x7f308867e910>,
#  <shapely.geometry.point.Point at 0x7f308867ecd0>,
#  <shapely.geometry.point.Point at 0x7f308867eb90>,
#  <shapely.geometry.point.Point at 0x7f308867ea90>,
#  <shapely.geometry.point.Point at 0x7f308867ee50>,
#  <shapely.geometry.point.Point at 0x7f308867ed10>,
#  <shapely.geometry.point.Point at 0x7f308867ec10>,
#  <shapely.geometry.point.Point at 0x7f308867efd0>,
#  <shapely.geometry.point.Point at 0x7f308867ee90>,
#  <shapely.geometry.point.Point at 0x7f308867ed90>,
#  <shapely.geometry.point.Point at 0x7f308867eed0>,
#  <shapely.geometry.point.Point at 0x7f308867ead0>,
#  <shapely.geometry.point.Point at 0x7f308867ea50>,
#  <shapely.geometry.point.Point at 0x7f308867ef50>,
#  <shapely.geometry.point.Point at 0x7f308867e550>,
#  <shapely.geometry.point.Point at 0x7f308867e6d0>,
#  <shapely.geometry.point.Point at 0x7f308867edd0>,
#  <shapely.geometry.point.Point at 0x7f308867ec50>,
#  <shapely.geometry.point.Point at 0x7f308867e950>,
#  <shapely.geometry.point.Point at 0x7f308867e8d0>,
#  <shapely.geometry.point.Point at 0x7f308867e5d0>,
#  <shapely.geometry.point.Point at 0x7f308869a390>,
#  <shapely.geometry.point.Point at 0x7f308869a090>,
#  <shapely.geometry.point.Point at 0x7f308869a0d0>,
#  <shapely.geometry.point.Point at 0x7f308869a050>,
#  <shapely.geometry.point.Point at 0x7f308869a190>,
#  <shapely.geometry.point.Point at 0x7f308869a1d0>,
#  <shapely.geometry.point.Point at 0x7f308869a150>,
#  <shapely.geometry.point.Point at 0x7f308869a290>,
#  <shapely.geometry.point.Point at 0x7f308869a2d0>,
#  <shapely.geometry.point.Point at 0x7f308869a250>,
#  <shapely.geometry.point.Point at 0x7f308869a450>,
#  <shapely.geometry.point.Point at 0x7f308869a490>,
#  <shapely.geometry.point.Point at 0x7f308869a310>,
#  <shapely.geometry.point.Point at 0x7f308869a510>,
#  <shapely.geometry.point.Point at 0x7f308869a550>,
#  <shapely.geometry.point.Point at 0x7f308869a4d0>,
#  <shapely.geometry.point.Point at 0x7f308869a610>,
#  <shapely.geometry.point.Point at 0x7f308869a650>,
#  <shapely.geometry.point.Point at 0x7f308869a5d0>,
#  <shapely.geometry.point.Point at 0x7f308869a710>,
#  <shapely.geometry.point.Point at 0x7f308869a750>,
#  <shapely.geometry.point.Point at 0x7f308869a6d0>,
#  <shapely.geometry.point.Point at 0x7f308869a810>,
#  <shapely.geometry.point.Point at 0x7f308869a850>,
#  <shapely.geometry.point.Point at 0x7f308869a7d0>,
#  <shapely.geometry.point.Point at 0x7f308869a9d0>,
#  <shapely.geometry.point.Point at 0x7f308869aa10>,
#  <shapely.geometry.point.Point at 0x7f308869a890>,
#  <shapely.geometry.point.Point at 0x7f308869a3d0>,
#  <shapely.geometry.point.Point at 0x7f308869ab90>,
#  <shapely.geometry.point.Point at 0x7f308869aa50>,
#  <shapely.geometry.point.Point at 0x7f308869a950>,
#  <shapely.geometry.point.Point at 0x7f308869ad10>,
#  <shapely.geometry.point.Point at 0x7f308869abd0>,
#  <shapely.geometry.point.Point at 0x7f308869ad90>,
#  <shapely.geometry.point.Point at 0x7f308869add0>,
#  <shapely.geometry.point.Point at 0x7f308869ad50>,
#  <shapely.geometry.point.Point at 0x7f308869ae90>,
#  <shapely.geometry.point.Point at 0x7f308869aed0>,
#  <shapely.geometry.point.Point at 0x7f308869ae50>,
#  <shapely.geometry.point.Point at 0x7f308869afd0>,
#  <shapely.geometry.point.Point at 0x7f308869af50>,
#  <shapely.geometry.point.Point at 0x7f308869ac50>,
#  <shapely.geometry.point.Point at 0x7f308869ac10>,
#  <shapely.geometry.point.Point at 0x7f308869ac90>,
#  <shapely.geometry.point.Point at 0x7f308869ab10>,
#  <shapely.geometry.point.Point at 0x7f308869a910>,
#  <shapely.geometry.point.Point at 0x7f308869a410>,
#  <shapely.geometry.point.Point at 0x7f308869aa90>,
#  <shapely.geometry.point.Point at 0x7f308868f050>,
#  <shapely.geometry.point.Point at 0x7f308868f0d0>,
#  <shapely.geometry.point.Point at 0x7f308868f110>,
#  <shapely.geometry.point.Point at 0x7f308868f090>,
#  <shapely.geometry.point.Point at 0x7f308868f290>,
#  <shapely.geometry.point.Point at 0x7f308868f2d0>,
#  <shapely.geometry.point.Point at 0x7f308868f150>,
#  <shapely.geometry.point.Point at 0x7f308868f350>,
#  <shapely.geometry.point.Point at 0x7f308868f390>,
#  ...]

# %%
geo_df = geopandas.GeoDataFrame(df1, geometry = g)

# %%
fig, ax = plt.subplots(figsize = (100,100))
states.plot(color='grey', ax=ax, alpha = 1)
geo_df.plot(color='red', markersize=5, ax=ax, label = 'Fire')

plt.title('Fire dots')
# Out:
# Text(0.5, 1, 'Fire dots')

# %%
2**16
# Out:
# 65536

# %%
#Proper printing code 

states = geopandas.read_file('/home/naveenggmu/Downloads/NASA data/Igismap/Indian_States.shp')
g = [Point(xy) for xy in zip(df1['longitude'], df1['latitude'])]
geo_df = geopandas.GeoDataFrame(df1, geometry = g)

fig, ax = plt.subplots(figsize = (15,15))
states.plot(color='grey', ax=ax, alpha = 1)
geo_df.plot(color='red', markersize=5, ax=ax, label = 'Fire')

plt.title('Fire dots')
# Out:
# Text(0.5, 1, 'Fire dots')

# %%
df1 = pd.read_csv('VIIRS_98825/fire_archive_V1_98825.csv')
df1.shape
# Out:
# (4430802, 14)

# %%
df1.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0   8.29995   77.60236       333.4  0.52   0.67  2012-01-20       724
# 1  10.67047   78.50570       331.5  0.41   0.61  2012-01-20       724
# 2  10.41370   79.31134       337.5  0.36   0.58  2012-01-20       724
# 3  15.17518   76.65643       367.0  0.45   0.63  2012-01-20       725
# 4  12.82341   75.97845       335.7  0.55   0.68  2012-01-20       725
#
#   satellite instrument confidence  version  bright_ti5   frp  type
# 0         N      VIIRS          n        1       295.4   4.7     0
# 1         N      VIIRS          n        1       300.6   1.1     0
# 2         N      VIIRS          n        1       300.0   1.5     0
# 3         N      VIIRS          h        1       305.1  11.1     2
# 4         N      VIIRS          n        1       301.2   6.3     0

# %%
df = pd.read_csv('VIIRS_98825/fire_nrt_V1_98825.csv')
df.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  20.78557   85.26518       335.2  0.42   0.38  2019-10-01       718
# 1  15.51146   79.84693       334.3  0.34   0.56  2019-10-01       718
# 2  22.79846   86.20762       334.0  0.39   0.36  2019-10-01       718
# 3  22.79787   86.20386       331.5  0.39   0.36  2019-10-01       718
# 4  22.06710   88.12332       341.2  0.39   0.36  2019-10-01       718
#
#   satellite instrument confidence version  bright_ti5  frp daynight
# 0         N      VIIRS          n  1.0NRT       295.7  5.8        D
# 1         N      VIIRS          n  1.0NRT       296.8  1.1        D
# 2         N      VIIRS          n  1.0NRT       297.5  6.6        D
# 3         N      VIIRS          n  1.0NRT       298.7  8.7        D
# 4         N      VIIRS          n  1.0NRT       294.6  9.4        D

# %%
df.shape
# Out:
# (99800, 14)

# %%
df.tail()
# Out:
#        latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 99795  15.17595   77.10375       306.0  0.43   0.62  2020-01-01      2106
# 99796  21.10789   72.63132       331.2  0.54   0.42  2020-01-01      2106
# 99797  20.93817   73.36703       300.4  0.40   0.44  2020-01-01      2106
# 99798  21.11027   72.63573       306.3  0.54   0.42  2020-01-01      2106
# 99799  21.11077   72.63725       301.5  0.54   0.42  2020-01-01      2106
#
#       satellite instrument confidence version  bright_ti5  frp daynight
# 99795         N      VIIRS          n  1.0NRT       289.0  1.2        N
# 99796         N      VIIRS          n  1.0NRT       289.2  3.7        N
# 99797         N      VIIRS          n  1.0NRT       284.6  0.7        N
# 99798         N      VIIRS          n  1.0NRT       289.2  3.7        N
# 99799         N      VIIRS          n  1.0NRT       288.4  1.1        N
